# %%
# goal of these notebooks is to compute the columns of the feature matrix X as outlined in Helmut's document
# we will use the DefAn QA dataset for our questions: https://github.com/ashikiut/defan
# these questions are designed to elicit definitive, concise, and informative answers,
# allowing us to more confidently rely on our LLM judge to determine reponse correctness.

# this first notebook is dedicated to producing a mindfully constructed input questions set.

import pandas as pd

pd.set_option("display.max_colwidth", None)

df = pd.read_json("DefAn/DefAn-Public Combined/DefAn_public_combined.json")
print(df.columns)
print(df.shape)
print(df["domain"].unique())
print(df["type"].unique())
display(df.describe(include='all').T)
# Out:
# Index(['questions', 'answer', 'type', 'domain'], dtype='str')
# (70793, 4)
# <ArrowStringArray>
# [             'Sports',    'Census Australia',         'Nobel Prize',
#        'entertainment', 'World Organizations',          'QS ranking',
#     'Conference venue',                'math']
# Length: 8, dtype: str
# <ArrowStringArray>
# ['name', 'numeric', 'date', 'rank', 'city']
# Length: 5, dtype: str
#            count unique  \
# questions  70793  70145
# answer     69713   4857
# type       70793      5
# domain     70793      8
#
#                                                                 top   freq
# questions  What is the birthdate (mm/dd/yyyy) of Katharine Hepburn?      6
# answer                                                            6    391
# type                                                        numeric  24278
# domain                                                   QS ranking  21495

# %%
# let's take a quick look inside the data
df.sample(20)
# Out:
#                                                                                                                                                                                                                                                                                                                                                            questions  \
# 44366                                                                                                                                                                                                                                                                                         What position did Tufts University attain in the QS rankings for 2023?
# 66683  a bowl of nuts is prepared for a party . brand p mixed nuts are 20 % almonds and brand q ' s deluxe nuts are 25 % almonds . if a bowl contains a total of 65 ounces of nuts , representing a mixture of both brands , and 15 ounces of the mixture are almonds , how many ounces of brand q ' s deluxe mixed nuts are used ?(Give me the numeric answer only)
# 12053                                                                                                                                                                                                                                           Who secured the Nobel Prize for Peace in 1946? [first name + last name only] if multiple person, give one name only.
# 31421                                                                                                                                                                                                                                                                                                     When was Ghana accepted as a member of the United Nations?
# 42873                                                                                                                                                                                                                                                                                       How did Universidad Autónoma de Madrid fare in the QS rankings for 2023?
# 41140                                                                                                                                                                                                                                                                                                           QS ranking of Sungkyunkwan University(SKKU) in 2023?
# 44202                                                                                                                                                                                                                                                                                                       What was Xi’an Jiaotong University's QS rating for 2023?
# 40182                                                                                                                                                                                                                                                                                                           What was University of Toronto's QS rating for 2023?
# 56536                                                                                                                                                            in a rectangular coordinate system , what is the area of a rectangle whose vertices have the coordinates ( - 7 , 1 ) , ( 1 , 1 ) , ( 1 , - 6 ) and ( - 7 , - 6 ) ?(Give me the numeric answer only)
# 65831                                                                                                                                                                                                                                                                              if ( 3 / 2 ) x - 3 = 15 what is the value of x ?(Give me the numeric answer only)
# 10855                                                                                                                                                                                                                               Who was honored with the Nobel Prize for Medicine in 1930? [first name + last name only] if multiple person, give one name only.
# 50526                                                                                                                                                                                                                                                                                   What was Indian Institute of Science's standing in the QS rankings for 2024?
# 51006                                                                                                                                                                                                                                                                                        What was Maastricht University 's standing in the QS rankings for 2024?
# 21161                                                                                                                                                                                                                                                          Who was awarded the Academy Awards/Oscars for Best actress in 1958? give first name + last name only.
# 25096                                                                                                                                                                                                                                                                                  Which film was awarded the Oscar for best picture in 2021?give one name only.
# 68382                                           a basketball is dropped from a height of 30 feet . if it bounces back up to a height that is exactly half of its previous height , and it stops bouncing after hitting the ground for the fourth time , then how many total feet will the ball have traveled after 2 full bounces .(Give me the numeric answer only)
# 28772                                                                                                                                                                                                                                                                                                   When did Hilary Swank celebrate their birthday (mm/dd/yyyy)?
# 30320                                                                                                                                                                                                                                                                                                What is the birth anniversary (mm/dd/yyyy) of Daniel Day-Lewis?
# 6719                                                                                                                                                                                                                                                                                                  population of South Australia in 2021 between 55-59  age group
# 61342                                                                                                                                                                                                       what two - digit number is less than the sum of the square of its digits by 10 and exceeds their doubled product by 5 ?(Give me the numeric answer only)
#
#                              answer     type               domain
# 44366                           312     rank           QS ranking
# 66683                            40  numeric                 math
# 12053  Emily Greene Balch;John Mott     name          Nobel Prize
# 31421                    03/08/1957     date  World Organizations
# 42873                           215     rank           QS ranking
# 41140                            99     rank           QS ranking
# 44202                           302     rank           QS ranking
# 40182                            34     rank           QS ranking
# 56536                            56  numeric                 math
# 65831                            12  numeric                 math
# 10855              Karl Landsteiner     name          Nobel Prize
# 50526                           225     rank           QS ranking
# 51006                           256     rank           QS ranking
# 21161                 Susan Hayward     name        entertainment
# 25096                          CODA     name        entertainment
# 68382                            75  numeric                 math
# 28772                    07/30/1974     date        entertainment
# 30320                    04/29/1957     date        entertainment
# 6719                        114,300  numeric     Census Australia
# 61342                            94  numeric                 math

# %%
# important for later: we need to remove certain extraneous instructions which appear in many of the questions in df

import re

phrases = [
    "(Give me the numeric answer only)",
    "Give me the exact location only.",
    "give first name + last name only.",
    "give one name only.",
    "give the movie name only.",
    "[first name + last name only] if multiple person, give one name only.",
    "(Give me the exact number only)",
    "(Give me the name only)",
]

# build a case-insensitive regex that matches any of the phrases literally
pattern = r"(?i)(" + "|".join(re.escape(p) for p in phrases) + r")"

df["questions"] = (
    df["questions"].astype(str)
      .str.replace(pattern, "", regex=True)             # remove phrases
      .str.replace(r"\s+", " ", regex=True)             # collapse whitespace
      .str.replace(r"\s+([?.!,;:])", r"\1", regex=True) # fix space before punctuation
      .str.strip()
)

df.sample(20)
# Out:
#                                                                                                                                                                                   questions  \
# 62682                                            there are, in a certain league, 20 teams, and each team face another team for a total of 4 times. how many games are played in the season?
# 25308                                                                                                                              In 1945, for which movie did Billy Wilder win the Oscar?
# 57371  a train 150 m long is running with a speed of 60 km / hr. in what time will it pass a man who is running at 6 km / hr in the direction opposite to that in which the train is going?
# 7430                                                                                                             How many residents aged 80-84 were recorded in Northern Territory in 2021?
# 42317                                                                                                                What was the QS ranking of Universitat Autònoma de Barcelona for 2023?
# 3993                                                                                                              In 2016, what was the number of people aged 45-49 residing in Queensland?
# 34350                                                                                  What was the position of University of California, Santa Barbara (UCSB) in the QS rankings for 2022?
# 27528                                                                                                            Who was the winner of the Academy Awards/Oscars for best director in 2007?
# 55331                                                                                                                                              What location accommodated ICCV in 2019?
# 68651                                                                                                    when 1 / 10 percent of 3,000 is subtracted from 1 / 10 of 3,000, the difference is
# 34038                                                                                                                           How did Monash University fare in the QS rankings for 2022?
# 56599                                                                                                                              how many different positive integers are factors of 125?
# 40149                                                                                                                      What QS ranking did The University of Melbourne achieve in 2023?
# 45003                                                                                                                       How did Universität Stuttgart fare in the QS rankings for 2023?
# 25332                                                                                                                      Which movie resulted in William Wyler earning the Oscar in 1946?
# 64208                                                                                                  how many even number in the range between 10 to 170 inclusive are not divisible by 3
# 16671                                                                                                                          Who was the laureate of the Nobel Prize for Physics in 1998?
# 43504                                                                                                                                        What was Mahidol University's QS rank in 2023?
# 3018                                                                                                         In 2016, what was the number of people aged 10-14 residing in New South Wales?
# 54620                                                                                                In 2024, what position did Rensselaer Polytechnic Institute secure in the QS rankings?
#
#                                                        answer     type  \
# 62682                                                     760  numeric
# 25308                                        The Lost Weekend     name
# 57371                                                       8  numeric
# 7430                                                    1,876  numeric
# 42317                                                     178     rank
# 3993                                                  322,982  numeric
# 34350                                                   146       rank
# 27528                                Joel Coen and Ethan Coen     name
# 55331                                            Seoul, Korea     city
# 68651                                                     397  numeric
# 34038                                                    58       rank
# 56599                                                       2  numeric
# 40149                                                      33     rank
# 45003                                                     355     rank
# 25332                             The Best Years of Our Lives     name
# 64208                                                      54  numeric
# 16671  Robert B. Laughlin;Horst Ludwig Störmer;Daniel C. Tsui     name
# 43504                                                     256     rank
# 3018                                                  443,009  numeric
# 54620                                                     494     rank
#
#                  domain
# 62682              math
# 25308     entertainment
# 57371              math
# 7430   Census Australia
# 42317        QS ranking
# 3993   Census Australia
# 34350        QS ranking
# 27528     entertainment
# 55331  Conference venue
# 68651              math
# 34038        QS ranking
# 56599              math
# 40149        QS ranking
# 45003        QS ranking
# 25332     entertainment
# 64208              math
# 16671       Nobel Prize
# 43504        QS ranking
# 3018   Census Australia
# 54620        QS ranking

# %%
# lets also check for missing values
for c in df.columns:
    print(df[c].isna().sum())
# Out:
# 0
# 1080
# 0
# 0

# %%
# any empty strings?
(df["answer"].str.strip() == "").sum()
# Out:
# np.int64(0)

# %%
# no empty strings -- let's see where the missing entries come from
missing_mask = df["answer"].isna()
df[missing_mask]["domain"].value_counts()
# Out:
# domain
# Nobel Prize    1080
# Name: count, dtype: int64

# %%
df[missing_mask].sample(20)
# Out:
#                                                                questions  \
# 10362                     Who won the Nobel Prize for Economics in 1924?
# 11059        In 1932, who was the recipient of the Nobel Prize in Peace?
# 10270        Who was honored with the Nobel Prize for Economics in 1923?
# 12250        Who was honored with the Nobel Prize for Economics in 1948?
# 12953                     Who secured the Nobel Prize for Peace in 1956?
# 10993             Who was granted the Nobel Prize for Economics in 1931?
# 12162                     Who won the Nobel Prize for Economics in 1947?
# 11784                    Who garnered the Nobel Prize for Peace in 1943?
# 11621  Who was the Nobel Prize recipient for Economics in the year 1938?
# 10453             Who was granted the Nobel Prize for Economics in 1925?
# 13332                     Who won the Nobel Prize for Economics in 1960?
# 13057       Who achieved the Nobel Prize in Economics for the year 1957?
# 13691  Who was the Nobel Prize recipient for Economics in the year 1964?
# 13508                 Who secured the Nobel Prize for Economics in 1962?
# 11760   Who was awarded the Nobel Prize in Literature for the year 1943?
# 9829     In 1907, who was the recipient of the Nobel Prize in Economics?
# 12879                Who garnered the Nobel Prize for Economics in 1955?
# 10627       Who achieved the Nobel Prize in Economics for the year 1927?
# 11250    Who was awarded the Nobel Prize in Economics for the year 1934?
# 10195        Who was honored with the Nobel Prize for Economics in 1911?
#
#       answer  type       domain
# 10362   None  name  Nobel Prize
# 11059   None  name  Nobel Prize
# 10270   None  name  Nobel Prize
# 12250   None  name  Nobel Prize
# 12953   None  name  Nobel Prize
# 10993   None  name  Nobel Prize
# 12162   None  name  Nobel Prize
# 11784   None  name  Nobel Prize
# 11621   None  name  Nobel Prize
# 10453   None  name  Nobel Prize
# 13332   None  name  Nobel Prize
# 13057   None  name  Nobel Prize
# 13691   None  name  Nobel Prize
# 13508   None  name  Nobel Prize
# 11760   None  name  Nobel Prize
# 9829    None  name  Nobel Prize
# 12879   None  name  Nobel Prize
# 10627   None  name  Nobel Prize
# 11250   None  name  Nobel Prize
# 10195   None  name  Nobel Prize

# %%
# the issue seems to be that no such Nobel Prizes were awarded for those years
# we'll populate the answers with a string informing our judge LLM as such
df.loc[missing_mask, "answer"] = "No such prize exists."

# now lets check for duplicates
df["questions"].duplicated().sum()
# Out:
# np.int64(648)

# %%
# it seems there's quite a few repeated questions. lets take a look

pd.set_option("display.max_rows", None)
duplicates = df[df["questions"].duplicated(keep=False)]
duplicates = duplicates.sort_values("questions")

print(duplicates.shape)
duplicates
# Out:
# (1224, 4)
#                                                                                       questions  \
# 30990                           At what date did Congo attain membership in the United Nations?
# 31110                           At what date did Congo attain membership in the United Nations?
# 30992                                At what date did Congo gain entry into the United Nations?
# 31112                                At what date did Congo gain entry into the United Nations?
# 31000                          At what date did Congo receive membership in the United Nations?
# 31120                          At what date did Congo receive membership in the United Nations?
# 30996                            At what date did Congo secure its place in the United Nations?
# 31116                            At what date did Congo secure its place in the United Nations?
# 30998                                 At what specific date did Congo enter the United Nations?
# 31118                                 At what specific date did Congo enter the United Nations?
# 24200                          In 1962, which film was honored with the Oscar for best picture?
# 24215                          In 1962, which film was honored with the Oscar for best picture?
# 24205                                  In 1962, which movie snagged the Oscar for best picture?
# 24220                                  In 1962, which movie snagged the Oscar for best picture?
# 24197                                In 1962, which movie took home the Oscar for best picture?
# 24212                                In 1962, which movie took home the Oscar for best picture?
# 660                  In what stadium did the final match of the 1930 FIFA World Cup take place?
# 990                  In what stadium did the final match of the 1930 FIFA World Cup take place?
# 668                               In what stadium was the 1930 FIFA World Cup final event held?
# 998                               In what stadium was the 1930 FIFA World Cup final event held?
# 674                        In which stadium did the 1930 FIFA World Cup come to its conclusion?
# 1004                       In which stadium did the 1930 FIFA World Cup come to its conclusion?
# 664                                   In which stadium did the 1930 FIFA World Cup final occur?
# 994                                   In which stadium did the 1930 FIFA World Cup final occur?
# 24208                           What film was bestowed with the Oscar for best picture in 1962?
# 24223                           What film was bestowed with the Oscar for best picture in 1962?
# 24198                                         What film won the Oscar for best picture in 1962?
# 24213                                         What film won the Oscar for best picture in 1962?
# 27838                                            What is Bette Davis's birth date (mm/dd/yyyy)?
# 27883                                            What is Bette Davis's birth date (mm/dd/yyyy)?
# 27834                                             What is Bette Davis's birthdate (mm/dd/yyyy)?
# 27879                                             What is Bette Davis's birthdate (mm/dd/yyyy)?
# 27828                                         What is Bette Davis's date of birth (mm/dd/yyyy)?
# 27873                                         What is Bette Davis's date of birth (mm/dd/yyyy)?
# 29878                                       What is Daniel Day-Lewis's birth date (mm/dd/yyyy)?
# 30148                                       What is Daniel Day-Lewis's birth date (mm/dd/yyyy)?
# 30328                                       What is Daniel Day-Lewis's birth date (mm/dd/yyyy)?
# 29874                                        What is Daniel Day-Lewis's birthdate (mm/dd/yyyy)?
# 30144                                        What is Daniel Day-Lewis's birthdate (mm/dd/yyyy)?
# 30324                                        What is Daniel Day-Lewis's birthdate (mm/dd/yyyy)?
# 29868                                    What is Daniel Day-Lewis's date of birth (mm/dd/yyyy)?
# 30138                                    What is Daniel Day-Lewis's date of birth (mm/dd/yyyy)?
# 30318                                    What is Daniel Day-Lewis's date of birth (mm/dd/yyyy)?
# 29728                                         What is Dustin Hoffman's birth date (mm/dd/yyyy)?
# 29863                                         What is Dustin Hoffman's birth date (mm/dd/yyyy)?
# 29724                                          What is Dustin Hoffman's birthdate (mm/dd/yyyy)?
# 29859                                          What is Dustin Hoffman's birthdate (mm/dd/yyyy)?
# 29718                                      What is Dustin Hoffman's date of birth (mm/dd/yyyy)?
# 29853                                      What is Dustin Hoffman's date of birth (mm/dd/yyyy)?
# 28738                                      What is Frances McDormand's birth date (mm/dd/yyyy)?
# 30298                                      What is Frances McDormand's birth date (mm/dd/yyyy)?
# 28734                                       What is Frances McDormand's birthdate (mm/dd/yyyy)?
# 30294                                       What is Frances McDormand's birthdate (mm/dd/yyyy)?
# 28728                                   What is Frances McDormand's date of birth (mm/dd/yyyy)?
# 30288                                   What is Frances McDormand's date of birth (mm/dd/yyyy)?
# 29158                                            What is Gary Cooper's birth date (mm/dd/yyyy)?
# 29323                                            What is Gary Cooper's birth date (mm/dd/yyyy)?
# 29154                                             What is Gary Cooper's birthdate (mm/dd/yyyy)?
# 29319                                             What is Gary Cooper's birthdate (mm/dd/yyyy)?
# 29148                                         What is Gary Cooper's date of birth (mm/dd/yyyy)?
# 29313                                         What is Gary Cooper's date of birth (mm/dd/yyyy)?
# 28348                                         What is Glenda Jackson's birth date (mm/dd/yyyy)?
# 28393                                         What is Glenda Jackson's birth date (mm/dd/yyyy)?
# 28344                                          What is Glenda Jackson's birthdate (mm/dd/yyyy)?
# 28389                                          What is Glenda Jackson's birthdate (mm/dd/yyyy)?
# 28338                                      What is Glenda Jackson's date of birth (mm/dd/yyyy)?
# 28383                                      What is Glenda Jackson's date of birth (mm/dd/yyyy)?
# 28783                                           What is Hilary Swank's birth date (mm/dd/yyyy)?
# 28858                                           What is Hilary Swank's birth date (mm/dd/yyyy)?
# 28779                                            What is Hilary Swank's birthdate (mm/dd/yyyy)?
# 28854                                            What is Hilary Swank's birthdate (mm/dd/yyyy)?
# 28773                                        What is Hilary Swank's date of birth (mm/dd/yyyy)?
# 28848                                        What is Hilary Swank's date of birth (mm/dd/yyyy)?
# 27973                                         What is Ingrid Bergman's birth date (mm/dd/yyyy)?
# 28153                                         What is Ingrid Bergman's birth date (mm/dd/yyyy)?
# 27969                                          What is Ingrid Bergman's birthdate (mm/dd/yyyy)?
# 28149                                          What is Ingrid Bergman's birthdate (mm/dd/yyyy)?
# 27963                                      What is Ingrid Bergman's date of birth (mm/dd/yyyy)?
# 28143                                      What is Ingrid Bergman's date of birth (mm/dd/yyyy)?
# 29668                                         What is Jack Nicholson's birth date (mm/dd/yyyy)?
# 29998                                         What is Jack Nicholson's birth date (mm/dd/yyyy)?
# 29664                                          What is Jack Nicholson's birthdate (mm/dd/yyyy)?
# 29994                                          What is Jack Nicholson's birthdate (mm/dd/yyyy)?
# 29658                                      What is Jack Nicholson's date of birth (mm/dd/yyyy)?
# 29988                                      What is Jack Nicholson's date of birth (mm/dd/yyyy)?
# 28363                                             What is Jane Fonda's birth date (mm/dd/yyyy)?
# 28468                                             What is Jane Fonda's birth date (mm/dd/yyyy)?
# 28359                                              What is Jane Fonda's birthdate (mm/dd/yyyy)?
# 28464                                              What is Jane Fonda's birthdate (mm/dd/yyyy)?
# 28353                                          What is Jane Fonda's date of birth (mm/dd/yyyy)?
# 28458                                          What is Jane Fonda's date of birth (mm/dd/yyyy)?
# 28618                                           What is Jodie Foster's birth date (mm/dd/yyyy)?
# 28663                                           What is Jodie Foster's birth date (mm/dd/yyyy)?
# 28614                                            What is Jodie Foster's birthdate (mm/dd/yyyy)?
# 28659                                            What is Jodie Foster's birthdate (mm/dd/yyyy)?
# 28608                                        What is Jodie Foster's date of birth (mm/dd/yyyy)?
# 28653                                        What is Jodie Foster's date of birth (mm/dd/yyyy)?
# 27808                                      What is Katharine Hepburn's birth date (mm/dd/yyyy)?
# 28318                                      What is Katharine Hepburn's birth date (mm/dd/yyyy)?
# 28513                                      What is Katharine Hepburn's birth date (mm/dd/yyyy)?
# 27804                                       What is Katharine Hepburn's birthdate (mm/dd/yyyy)?
# 28314                                       What is Katharine Hepburn's birthdate (mm/dd/yyyy)?
# 28509                                       What is Katharine Hepburn's birthdate (mm/dd/yyyy)?
# 27798                                   What is Katharine Hepburn's date of birth (mm/dd/yyyy)?
# 28308                                   What is Katharine Hepburn's date of birth (mm/dd/yyyy)?
# 28503                                   What is Katharine Hepburn's date of birth (mm/dd/yyyy)?
# 27853                                           What is Luise Rainer's birth date (mm/dd/yyyy)?
# 27868                                           What is Luise Rainer's birth date (mm/dd/yyyy)?
# 27849                                            What is Luise Rainer's birthdate (mm/dd/yyyy)?
# 27864                                            What is Luise Rainer's birthdate (mm/dd/yyyy)?
# 27843                                        What is Luise Rainer's date of birth (mm/dd/yyyy)?
# 27858                                        What is Luise Rainer's date of birth (mm/dd/yyyy)?
# 29353                                          What is Marlon Brando's birth date (mm/dd/yyyy)?
# 29623                                          What is Marlon Brando's birth date (mm/dd/yyyy)?
# 29349                                           What is Marlon Brando's birthdate (mm/dd/yyyy)?
# 29619                                           What is Marlon Brando's birthdate (mm/dd/yyyy)?
# 29343                                       What is Marlon Brando's date of birth (mm/dd/yyyy)?
# 29613                                       What is Marlon Brando's date of birth (mm/dd/yyyy)?
# 28528                                           What is Meryl Streep's birth date (mm/dd/yyyy)?
# 28963                                           What is Meryl Streep's birth date (mm/dd/yyyy)?
# 28524                                            What is Meryl Streep's birthdate (mm/dd/yyyy)?
# 28959                                            What is Meryl Streep's birthdate (mm/dd/yyyy)?
# 28518                                        What is Meryl Streep's date of birth (mm/dd/yyyy)?
# 28953                                        What is Meryl Streep's date of birth (mm/dd/yyyy)?
# 28003                                    What is Olivia de Havilland's birth date (mm/dd/yyyy)?
# 28048                                    What is Olivia de Havilland's birth date (mm/dd/yyyy)?
# 27999                                     What is Olivia de Havilland's birthdate (mm/dd/yyyy)?
# 28044                                     What is Olivia de Havilland's birthdate (mm/dd/yyyy)?
# 27993                                 What is Olivia de Havilland's date of birth (mm/dd/yyyy)?
# 28038                                 What is Olivia de Havilland's date of birth (mm/dd/yyyy)?
# 28483                                            What is Sally Field's birth date (mm/dd/yyyy)?
# 28558                                            What is Sally Field's birth date (mm/dd/yyyy)?
# 28479                                             What is Sally Field's birthdate (mm/dd/yyyy)?
# 28554                                             What is Sally Field's birthdate (mm/dd/yyyy)?
# 28473                                         What is Sally Field's date of birth (mm/dd/yyyy)?
# 28548                                         What is Sally Field's date of birth (mm/dd/yyyy)?
# 30088                                              What is Sean Penn's birth date (mm/dd/yyyy)?
# 30163                                              What is Sean Penn's birth date (mm/dd/yyyy)?
# 30084                                               What is Sean Penn's birthdate (mm/dd/yyyy)?
# 30159                                               What is Sean Penn's birthdate (mm/dd/yyyy)?
# 30078                                           What is Sean Penn's date of birth (mm/dd/yyyy)?
# 30153                                           What is Sean Penn's date of birth (mm/dd/yyyy)?
# 29098                                          What is Spencer Tracy's birth date (mm/dd/yyyy)?
# 29113                                          What is Spencer Tracy's birth date (mm/dd/yyyy)?
# 29094                                           What is Spencer Tracy's birthdate (mm/dd/yyyy)?
# 29109                                           What is Spencer Tracy's birthdate (mm/dd/yyyy)?
# 29088                                       What is Spencer Tracy's date of birth (mm/dd/yyyy)?
# 29103                                       What is Spencer Tracy's date of birth (mm/dd/yyyy)?
# 29938                                              What is Tom Hanks's birth date (mm/dd/yyyy)?
# 29953                                              What is Tom Hanks's birth date (mm/dd/yyyy)?
# 29934                                               What is Tom Hanks's birthdate (mm/dd/yyyy)?
# 29949                                               What is Tom Hanks's birthdate (mm/dd/yyyy)?
# 29928                                           What is Tom Hanks's date of birth (mm/dd/yyyy)?
# 29943                                           What is Tom Hanks's date of birth (mm/dd/yyyy)?
# 27898                                           What is Vivien Leigh's birth date (mm/dd/yyyy)?
# 28078                                           What is Vivien Leigh's birth date (mm/dd/yyyy)?
# 27894                                            What is Vivien Leigh's birthdate (mm/dd/yyyy)?
# 28074                                            What is Vivien Leigh's birthdate (mm/dd/yyyy)?
# 27888                                        What is Vivien Leigh's date of birth (mm/dd/yyyy)?
# 28068                                        What is Vivien Leigh's date of birth (mm/dd/yyyy)?
# 27830                                What is the birth anniversary (mm/dd/yyyy) of Bette Davis?
# 27875                                What is the birth anniversary (mm/dd/yyyy) of Bette Davis?
# 29870                           What is the birth anniversary (mm/dd/yyyy) of Daniel Day-Lewis?
# 30140                           What is the birth anniversary (mm/dd/yyyy) of Daniel Day-Lewis?
# 30320                           What is the birth anniversary (mm/dd/yyyy) of Daniel Day-Lewis?
# 29720                             What is the birth anniversary (mm/dd/yyyy) of Dustin Hoffman?
# 29855                             What is the birth anniversary (mm/dd/yyyy) of Dustin Hoffman?
# 28730                          What is the birth anniversary (mm/dd/yyyy) of Frances McDormand?
# 30290                          What is the birth anniversary (mm/dd/yyyy) of Frances McDormand?
# 29150                                What is the birth anniversary (mm/dd/yyyy) of Gary Cooper?
# 29315                                What is the birth anniversary (mm/dd/yyyy) of Gary Cooper?
# 28340                             What is the birth anniversary (mm/dd/yyyy) of Glenda Jackson?
# 28385                             What is the birth anniversary (mm/dd/yyyy) of Glenda Jackson?
# 28775                               What is the birth anniversary (mm/dd/yyyy) of Hilary Swank?
# 28850                               What is the birth anniversary (mm/dd/yyyy) of Hilary Swank?
# 27965                             What is the birth anniversary (mm/dd/yyyy) of Ingrid Bergman?
# 28145                             What is the birth anniversary (mm/dd/yyyy) of Ingrid Bergman?
# 29660                             What is the birth anniversary (mm/dd/yyyy) of Jack Nicholson?
# 29990                             What is the birth anniversary (mm/dd/yyyy) of Jack Nicholson?
# 28355                                 What is the birth anniversary (mm/dd/yyyy) of Jane Fonda?
# 28460                                 What is the birth anniversary (mm/dd/yyyy) of Jane Fonda?
# 28610                               What is the birth anniversary (mm/dd/yyyy) of Jodie Foster?
# 28655                               What is the birth anniversary (mm/dd/yyyy) of Jodie Foster?
# 27800                          What is the birth anniversary (mm/dd/yyyy) of Katharine Hepburn?
# 28310                          What is the birth anniversary (mm/dd/yyyy) of Katharine Hepburn?
# 28505                          What is the birth anniversary (mm/dd/yyyy) of Katharine Hepburn?
# 27845                               What is the birth anniversary (mm/dd/yyyy) of Luise Rainer?
# 27860                               What is the birth anniversary (mm/dd/yyyy) of Luise Rainer?
# 29345                              What is the birth anniversary (mm/dd/yyyy) of Marlon Brando?
# 29615                              What is the birth anniversary (mm/dd/yyyy) of Marlon Brando?
# 28520                               What is the birth anniversary (mm/dd/yyyy) of Meryl Streep?
# 28955                               What is the birth anniversary (mm/dd/yyyy) of Meryl Streep?
# 27995                        What is the birth anniversary (mm/dd/yyyy) of Olivia de Havilland?
# 28040                        What is the birth anniversary (mm/dd/yyyy) of Olivia de Havilland?
# 28475                                What is the birth anniversary (mm/dd/yyyy) of Sally Field?
# 28550                                What is the birth anniversary (mm/dd/yyyy) of Sally Field?
# 30080                                  What is the birth anniversary (mm/dd/yyyy) of Sean Penn?
# 30155                                  What is the birth anniversary (mm/dd/yyyy) of Sean Penn?
# 29090                              What is the birth anniversary (mm/dd/yyyy) of Spencer Tracy?
# 29105                              What is the birth anniversary (mm/dd/yyyy) of Spencer Tracy?
# 29930                                  What is the birth anniversary (mm/dd/yyyy) of Tom Hanks?
# 29945                                  What is the birth anniversary (mm/dd/yyyy) of Tom Hanks?
# 27890                               What is the birth anniversary (mm/dd/yyyy) of Vivien Leigh?
# 28070                               What is the birth anniversary (mm/dd/yyyy) of Vivien Leigh?
# 27832                                        What is the birth day (mm/dd/yyyy) of Bette Davis?
# 27877                                        What is the birth day (mm/dd/yyyy) of Bette Davis?
# 29872                                   What is the birth day (mm/dd/yyyy) of Daniel Day-Lewis?
# 30142                                   What is the birth day (mm/dd/yyyy) of Daniel Day-Lewis?
# 30322                                   What is the birth day (mm/dd/yyyy) of Daniel Day-Lewis?
# 29722                                     What is the birth day (mm/dd/yyyy) of Dustin Hoffman?
# 29857                                     What is the birth day (mm/dd/yyyy) of Dustin Hoffman?
# 28732                                  What is the birth day (mm/dd/yyyy) of Frances McDormand?
# 30292                                  What is the birth day (mm/dd/yyyy) of Frances McDormand?
# 29152                                        What is the birth day (mm/dd/yyyy) of Gary Cooper?
# 29317                                        What is the birth day (mm/dd/yyyy) of Gary Cooper?
# 28342                                     What is the birth day (mm/dd/yyyy) of Glenda Jackson?
# 28387                                     What is the birth day (mm/dd/yyyy) of Glenda Jackson?
# 28777                                       What is the birth day (mm/dd/yyyy) of Hilary Swank?
# 28852                                       What is the birth day (mm/dd/yyyy) of Hilary Swank?
# 27967                                     What is the birth day (mm/dd/yyyy) of Ingrid Bergman?
# 28147                                     What is the birth day (mm/dd/yyyy) of Ingrid Bergman?
# 29662                                     What is the birth day (mm/dd/yyyy) of Jack Nicholson?
# 29992                                     What is the birth day (mm/dd/yyyy) of Jack Nicholson?
# 28357                                         What is the birth day (mm/dd/yyyy) of Jane Fonda?
# 28462                                         What is the birth day (mm/dd/yyyy) of Jane Fonda?
# 28612                                       What is the birth day (mm/dd/yyyy) of Jodie Foster?
# 28657                                       What is the birth day (mm/dd/yyyy) of Jodie Foster?
# 27802                                  What is the birth day (mm/dd/yyyy) of Katharine Hepburn?
# 28312                                  What is the birth day (mm/dd/yyyy) of Katharine Hepburn?
# 28507                                  What is the birth day (mm/dd/yyyy) of Katharine Hepburn?
# 27847                                       What is the birth day (mm/dd/yyyy) of Luise Rainer?
# 27862                                       What is the birth day (mm/dd/yyyy) of Luise Rainer?
# 29347                                      What is the birth day (mm/dd/yyyy) of Marlon Brando?
# 29617                                      What is the birth day (mm/dd/yyyy) of Marlon Brando?
# 28522                                       What is the birth day (mm/dd/yyyy) of Meryl Streep?
# 28957                                       What is the birth day (mm/dd/yyyy) of Meryl Streep?
# 27997                                What is the birth day (mm/dd/yyyy) of Olivia de Havilland?
# 28042                                What is the birth day (mm/dd/yyyy) of Olivia de Havilland?
# 28477                                        What is the birth day (mm/dd/yyyy) of Sally Field?
# 28552                                        What is the birth day (mm/dd/yyyy) of Sally Field?
# 30082                                          What is the birth day (mm/dd/yyyy) of Sean Penn?
# 30157                                          What is the birth day (mm/dd/yyyy) of Sean Penn?
# 29092                                      What is the birth day (mm/dd/yyyy) of Spencer Tracy?
# 29107                                      What is the birth day (mm/dd/yyyy) of Spencer Tracy?
# 29932                                          What is the birth day (mm/dd/yyyy) of Tom Hanks?
# 29947                                          What is the birth day (mm/dd/yyyy) of Tom Hanks?
# 27892                                       What is the birth day (mm/dd/yyyy) of Vivien Leigh?
# 28072                                       What is the birth day (mm/dd/yyyy) of Vivien Leigh?
# 30061                                       What is the birthdate (mm/dd/yyyy) of Adrien Brody?
# 30071                                       What is the birthdate (mm/dd/yyyy) of Adrien Brody?
# 29911                                          What is the birthdate (mm/dd/yyyy) of Al Pacino?
# 29921                                          What is the birthdate (mm/dd/yyyy) of Al Pacino?
# 29386                                      What is the birthdate (mm/dd/yyyy) of Alec Guinness?
# 29396                                      What is the birthdate (mm/dd/yyyy) of Alec Guinness?
# 28126                                       What is the birthdate (mm/dd/yyyy) of Anna Magnani?
# 28136                                       What is the birthdate (mm/dd/yyyy) of Anna Magnani?
# 28231                                      What is the birthdate (mm/dd/yyyy) of Anne Bancroft?
# 28241                                      What is the birthdate (mm/dd/yyyy) of Anne Bancroft?
# 29896                                    What is the birthdate (mm/dd/yyyy) of Anthony Hopkins?
# 29906                                    What is the birthdate (mm/dd/yyyy) of Anthony Hopkins?
# 29641                                         What is the birthdate (mm/dd/yyyy) of Art Carney?
# 29651                                         What is the birthdate (mm/dd/yyyy) of Art Carney?
# 28096                                     What is the birthdate (mm/dd/yyyy) of Audrey Hepburn?
# 28106                                     What is the birthdate (mm/dd/yyyy) of Audrey Hepburn?
# 29761                                       What is the birthdate (mm/dd/yyyy) of Ben Kingsley?
# 29771                                       What is the birthdate (mm/dd/yyyy) of Ben Kingsley?
# 27826                                        What is the birthdate (mm/dd/yyyy) of Bette Davis?
# 27836                                        What is the birthdate (mm/dd/yyyy) of Bette Davis?
# 27871                                        What is the birthdate (mm/dd/yyyy) of Bette Davis?
# 27881                                        What is the birthdate (mm/dd/yyyy) of Bette Davis?
# 29191                                        What is the birthdate (mm/dd/yyyy) of Bing Crosby?
# 29201                                        What is the birthdate (mm/dd/yyyy) of Bing Crosby?
# 30256                                        What is the birthdate (mm/dd/yyyy) of Brie Larson?
# 30266                                        What is the birthdate (mm/dd/yyyy) of Brie Larson?
# 29266                                 What is the birthdate (mm/dd/yyyy) of Broderick Crawford?
# 29276                                 What is the birthdate (mm/dd/yyyy) of Broderick Crawford?
# 29431                                     What is the birthdate (mm/dd/yyyy) of Burt Lancaster?
# 29441                                     What is the birthdate (mm/dd/yyyy) of Burt Lancaster?
# 30376                                      What is the birthdate (mm/dd/yyyy) of Casey Affleck?
# 30386                                      What is the birthdate (mm/dd/yyyy) of Casey Affleck?
# 30226                                     What is the birthdate (mm/dd/yyyy) of Cate Blanchett?
# 30236                                     What is the birthdate (mm/dd/yyyy) of Cate Blanchett?
# 29026                                   What is the birthdate (mm/dd/yyyy) of Charles Laughton?
# 29036                                   What is the birthdate (mm/dd/yyyy) of Charles Laughton?
# 28831                                    What is the birthdate (mm/dd/yyyy) of Charlize Theron?
# 28841                                    What is the birthdate (mm/dd/yyyy) of Charlize Theron?
# 29416                                    What is the birthdate (mm/dd/yyyy) of Charlton Heston?
# 29426                                    What is the birthdate (mm/dd/yyyy) of Charlton Heston?
# 28591                                               What is the birthdate (mm/dd/yyyy) of Cher?
# 28601                                               What is the birthdate (mm/dd/yyyy) of Cher?
# 29041                                        What is the birthdate (mm/dd/yyyy) of Clark Gable?
# 29051                                        What is the birthdate (mm/dd/yyyy) of Clark Gable?
# 27811                                  What is the birthdate (mm/dd/yyyy) of Claudette Colbert?
# 27821                                  What is the birthdate (mm/dd/yyyy) of Claudette Colbert?
# 29551                                    What is the birthdate (mm/dd/yyyy) of Cliff Robertson?
# 29561                                    What is the birthdate (mm/dd/yyyy) of Cliff Robertson?
# 30181                                        What is the birthdate (mm/dd/yyyy) of Colin Firth?
# 30191                                        What is the birthdate (mm/dd/yyyy) of Colin Firth?
# 29866                                   What is the birthdate (mm/dd/yyyy) of Daniel Day-Lewis?
# 29876                                   What is the birthdate (mm/dd/yyyy) of Daniel Day-Lewis?
# 30136                                   What is the birthdate (mm/dd/yyyy) of Daniel Day-Lewis?
# 30146                                   What is the birthdate (mm/dd/yyyy) of Daniel Day-Lewis?
# 30316                                   What is the birthdate (mm/dd/yyyy) of Daniel Day-Lewis?
# 30326                                   What is the birthdate (mm/dd/yyyy) of Daniel Day-Lewis?
# 29401                                        What is the birthdate (mm/dd/yyyy) of David Niven?
# 29411                                        What is the birthdate (mm/dd/yyyy) of David Niven?
# 30046                                  What is the birthdate (mm/dd/yyyy) of Denzel Washington?
# 30056                                  What is the birthdate (mm/dd/yyyy) of Denzel Washington?
# 28441                                       What is the birthdate (mm/dd/yyyy) of Diane Keaton?
# 28451                                       What is the birthdate (mm/dd/yyyy) of Diane Keaton?
# 29716                                     What is the birthdate (mm/dd/yyyy) of Dustin Hoffman?
# 29726                                     What is the birthdate (mm/dd/yyyy) of Dustin Hoffman?
# 29851                                     What is the birthdate (mm/dd/yyyy) of Dustin Hoffman?
# 29861                                     What is the birthdate (mm/dd/yyyy) of Dustin Hoffman?
# 30346                                     What is the birthdate (mm/dd/yyyy) of Eddie Redmayne?
# 30356                                     What is the birthdate (mm/dd/yyyy) of Eddie Redmayne?
# 28201                                   What is the birthdate (mm/dd/yyyy) of Elisabeth Taylor?
# 28211                                   What is the birthdate (mm/dd/yyyy) of Elisabeth Taylor?
# 28291                                   What is the birthdate (mm/dd/yyyy) of Elizabeth Taylor?
# 28301                                   What is the birthdate (mm/dd/yyyy) of Elizabeth Taylor?
# 28396                                      What is the birthdate (mm/dd/yyyy) of Ellen Burstyn?
# 28406                                      What is the birthdate (mm/dd/yyyy) of Ellen Burstyn?
# 28966                                      What is the birthdate (mm/dd/yyyy) of Emil Jannings?
# 28976                                      What is the birthdate (mm/dd/yyyy) of Emil Jannings?
# 30271                                         What is the birthdate (mm/dd/yyyy) of Emma Stone?
# 30281                                         What is the birthdate (mm/dd/yyyy) of Emma Stone?
# 28666                                      What is the birthdate (mm/dd/yyyy) of Emma Thompson?
# 28676                                      What is the birthdate (mm/dd/yyyy) of Emma Thompson?
# 29356                                    What is the birthdate (mm/dd/yyyy) of Ernest Borgnine?
# 29366                                    What is the birthdate (mm/dd/yyyy) of Ernest Borgnine?
# 29791                                  What is the birthdate (mm/dd/yyyy) of F. Murray Abraham?
# 29801                                  What is the birthdate (mm/dd/yyyy) of F. Murray Abraham?
# 28426                                       What is the birthdate (mm/dd/yyyy) of Faye Dunaway?
# 28436                                       What is the birthdate (mm/dd/yyyy) of Faye Dunaway?
# 30121                                    What is the birthdate (mm/dd/yyyy) of Forest Whitaker?
# 30131                                    What is the birthdate (mm/dd/yyyy) of Forest Whitaker?
# 28726                                  What is the birthdate (mm/dd/yyyy) of Frances McDormand?
# 28736                                  What is the birthdate (mm/dd/yyyy) of Frances McDormand?
# 30286                                  What is the birthdate (mm/dd/yyyy) of Frances McDormand?
# 30296                                  What is the birthdate (mm/dd/yyyy) of Frances McDormand?
# 29221                                      What is the birthdate (mm/dd/yyyy) of Fredric March?
# 29231                                      What is the birthdate (mm/dd/yyyy) of Fredric March?
# 29146                                        What is the birthdate (mm/dd/yyyy) of Gary Cooper?
# 29156                                        What is the birthdate (mm/dd/yyyy) of Gary Cooper?
# 29311                                        What is the birthdate (mm/dd/yyyy) of Gary Cooper?
# 29321                                        What is the birthdate (mm/dd/yyyy) of Gary Cooper?
# 30391                                        What is the birthdate (mm/dd/yyyy) of Gary Oldman?
# 30401                                        What is the birthdate (mm/dd/yyyy) of Gary Oldman?
# 29596                                       What is the birthdate (mm/dd/yyyy) of Gene Hackman?
# 29606                                       What is the birthdate (mm/dd/yyyy) of Gene Hackman?
# 29971                                      What is the birthdate (mm/dd/yyyy) of Geoffrey Rush?
# 29981                                      What is the birthdate (mm/dd/yyyy) of Geoffrey Rush?
# 28996                                      What is the birthdate (mm/dd/yyyy) of George Arliss?
# 29006                                      What is the birthdate (mm/dd/yyyy) of George Arliss?
# 29581                                    What is the birthdate (mm/dd/yyyy) of George C. Scott?
# 29591                                    What is the birthdate (mm/dd/yyyy) of George C. Scott?
# 28561                                     What is the birthdate (mm/dd/yyyy) of Geraldine Page?
# 28571                                     What is the birthdate (mm/dd/yyyy) of Geraldine Page?
# 27901                                      What is the birthdate (mm/dd/yyyy) of Ginger Rogers?
# 27911                                      What is the birthdate (mm/dd/yyyy) of Ginger Rogers?
# 28336                                     What is the birthdate (mm/dd/yyyy) of Glenda Jackson?
# 28346                                     What is the birthdate (mm/dd/yyyy) of Glenda Jackson?
# 28381                                     What is the birthdate (mm/dd/yyyy) of Glenda Jackson?
# 28391                                     What is the birthdate (mm/dd/yyyy) of Glenda Jackson?
# 28111                                        What is the birthdate (mm/dd/yyyy) of Grace Kelly?
# 28121                                        What is the birthdate (mm/dd/yyyy) of Grace Kelly?
# 27931                                       What is the birthdate (mm/dd/yyyy) of Greer Garson?
# 27941                                       What is the birthdate (mm/dd/yyyy) of Greer Garson?
# 29461                                       What is the birthdate (mm/dd/yyyy) of Gregory Peck?
# 29471                                       What is the birthdate (mm/dd/yyyy) of Gregory Peck?
# 28756                                    What is the birthdate (mm/dd/yyyy) of Gwyneth Paltrow?
# 28766                                    What is the birthdate (mm/dd/yyyy) of Gwyneth Paltrow?
# 28801                                        What is the birthdate (mm/dd/yyyy) of Halle Berry?
# 28811                                        What is the birthdate (mm/dd/yyyy) of Halle Berry?
# 27781                                        What is the birthdate (mm/dd/yyyy) of Helen Hayes?
# 27791                                        What is the birthdate (mm/dd/yyyy) of Helen Hayes?
# 28741                                         What is the birthdate (mm/dd/yyyy) of Helen Hunt?
# 28751                                         What is the birthdate (mm/dd/yyyy) of Helen Hunt?
# 28876                                       What is the birthdate (mm/dd/yyyy) of Helen Mirren?
# 28886                                       What is the birthdate (mm/dd/yyyy) of Helen Mirren?
# 29746                                        What is the birthdate (mm/dd/yyyy) of Henry Fonda?
# 29756                                        What is the birthdate (mm/dd/yyyy) of Henry Fonda?
# 28771                                       What is the birthdate (mm/dd/yyyy) of Hilary Swank?
# 28781                                       What is the birthdate (mm/dd/yyyy) of Hilary Swank?
# 28846                                       What is the birthdate (mm/dd/yyyy) of Hilary Swank?
# 28856                                       What is the birthdate (mm/dd/yyyy) of Hilary Swank?
# 28681                                       What is the birthdate (mm/dd/yyyy) of Holly Hunter?
# 28691                                       What is the birthdate (mm/dd/yyyy) of Holly Hunter?
# 29296                                    What is the birthdate (mm/dd/yyyy) of Humphrey Bogart?
# 29306                                    What is the birthdate (mm/dd/yyyy) of Humphrey Bogart?
# 27961                                     What is the birthdate (mm/dd/yyyy) of Ingrid Bergman?
# 27971                                     What is the birthdate (mm/dd/yyyy) of Ingrid Bergman?
# 28141                                     What is the birthdate (mm/dd/yyyy) of Ingrid Bergman?
# 28151                                     What is the birthdate (mm/dd/yyyy) of Ingrid Bergman?
# 29626                                        What is the birthdate (mm/dd/yyyy) of Jack Lemmon?
# 29636                                        What is the birthdate (mm/dd/yyyy) of Jack Lemmon?
# 29656                                     What is the birthdate (mm/dd/yyyy) of Jack Nicholson?
# 29666                                     What is the birthdate (mm/dd/yyyy) of Jack Nicholson?
# 29986                                     What is the birthdate (mm/dd/yyyy) of Jack Nicholson?
# 29996                                     What is the birthdate (mm/dd/yyyy) of Jack Nicholson?
# 29161                                       What is the birthdate (mm/dd/yyyy) of James Cagney?
# 29171                                       What is the birthdate (mm/dd/yyyy) of James Cagney?
# 29131                                      What is the birthdate (mm/dd/yyyy) of James Stewart?
# 29141                                      What is the birthdate (mm/dd/yyyy) of James Stewart?
# 30091                                         What is the birthdate (mm/dd/yyyy) of Jamie Foxx?
# 30101                                         What is the birthdate (mm/dd/yyyy) of Jamie Foxx?
# 28351                                         What is the birthdate (mm/dd/yyyy) of Jane Fonda?
# 28361                                         What is the birthdate (mm/dd/yyyy) of Jane Fonda?
# 28456                                         What is the birthdate (mm/dd/yyyy) of Jane Fonda?
# 28466                                         What is the birthdate (mm/dd/yyyy) of Jane Fonda?
# 28021                                         What is the birthdate (mm/dd/yyyy) of Jane Wyman?
# 28031                                         What is the birthdate (mm/dd/yyyy) of Jane Wyman?
# 27721                                       What is the birthdate (mm/dd/yyyy) of Janet Gaynor?
# 27731                                       What is the birthdate (mm/dd/yyyy) of Janet Gaynor?
# 30196                                      What is the birthdate (mm/dd/yyyy) of Jean Dujardin?
# 30206                                      What is the birthdate (mm/dd/yyyy) of Jean Dujardin?
# 30166                                       What is the birthdate (mm/dd/yyyy) of Jeff Bridges?
# 30176                                       What is the birthdate (mm/dd/yyyy) of Jeff Bridges?
# 27946                                     What is the birthdate (mm/dd/yyyy) of Jennifer Jones?
# 27956                                     What is the birthdate (mm/dd/yyyy) of Jennifer Jones?
# 30211                                  What is the birthdate (mm/dd/yyyy) of Jennifer Lawrence?
# 30221                                  What is the birthdate (mm/dd/yyyy) of Jennifer Lawrence?
# 29881                                       What is the birthdate (mm/dd/yyyy) of Jeremy Irons?
# 29891                                       What is the birthdate (mm/dd/yyyy) of Jeremy Irons?
# 28696                                      What is the birthdate (mm/dd/yyyy) of Jessica Lange?
# 28706                                      What is the birthdate (mm/dd/yyyy) of Jessica Lange?
# 28621                                      What is the birthdate (mm/dd/yyyy) of Jessica Tandy?
# 28631                                      What is the birthdate (mm/dd/yyyy) of Jessica Tandy?
# 27976                                      What is the birthdate (mm/dd/yyyy) of Joan Crawford?
# 27986                                      What is the birthdate (mm/dd/yyyy) of Joan Crawford?
# 27916                                      What is the birthdate (mm/dd/yyyy) of Joan Fontaine?
# 27926                                      What is the birthdate (mm/dd/yyyy) of Joan Fontaine?
# 28156                                    What is the birthdate (mm/dd/yyyy) of Joanne Woodward?
# 28166                                    What is the birthdate (mm/dd/yyyy) of Joanne Woodward?
# 28606                                       What is the birthdate (mm/dd/yyyy) of Jodie Foster?
# 28616                                       What is the birthdate (mm/dd/yyyy) of Jodie Foster?
# 28651                                       What is the birthdate (mm/dd/yyyy) of Jodie Foster?
# 28661                                       What is the birthdate (mm/dd/yyyy) of Jodie Foster?
# 29566                                         What is the birthdate (mm/dd/yyyy) of John Wayne?
# 29576                                         What is the birthdate (mm/dd/yyyy) of John Wayne?
# 29701                                         What is the birthdate (mm/dd/yyyy) of Jon Voight?
# 29711                                         What is the birthdate (mm/dd/yyyy) of Jon Voight?
# 29281                                        What is the birthdate (mm/dd/yyyy) of Jose Ferrer?
# 29291                                        What is the birthdate (mm/dd/yyyy) of Jose Ferrer?
# 28051                                      What is the birthdate (mm/dd/yyyy) of Judy Holliday?
# 28061                                      What is the birthdate (mm/dd/yyyy) of Judy Holliday?
# 28786                                      What is the birthdate (mm/dd/yyyy) of Julia Roberts?
# 28796                                      What is the birthdate (mm/dd/yyyy) of Julia Roberts?
# 30241                                     What is the birthdate (mm/dd/yyyy) of Julianne Moore?
# 30251                                     What is the birthdate (mm/dd/yyyy) of Julianne Moore?
# 28261                                      What is the birthdate (mm/dd/yyyy) of Julie Andrews?
# 28271                                      What is the birthdate (mm/dd/yyyy) of Julie Andrews?
# 28276                                     What is the birthdate (mm/dd/yyyy) of Julie Christie?
# 28286                                     What is the birthdate (mm/dd/yyyy) of Julie Christie?
# 28906                                       What is the birthdate (mm/dd/yyyy) of Kate Winslet?
# 28916                                       What is the birthdate (mm/dd/yyyy) of Kate Winslet?
# 27796                                  What is the birthdate (mm/dd/yyyy) of Katharine Hepburn?
# 27806                                  What is the birthdate (mm/dd/yyyy) of Katharine Hepburn?
# 28306                                  What is the birthdate (mm/dd/yyyy) of Katharine Hepburn?
# 28316                                  What is the birthdate (mm/dd/yyyy) of Katharine Hepburn?
# 28501                                  What is the birthdate (mm/dd/yyyy) of Katharine Hepburn?
# 28511                                  What is the birthdate (mm/dd/yyyy) of Katharine Hepburn?
# 28636                                        What is the birthdate (mm/dd/yyyy) of Kathy Bates?
# 28646                                        What is the birthdate (mm/dd/yyyy) of Kathy Bates?
# 30016                                       What is the birthdate (mm/dd/yyyy) of Kevin Spacey?
# 30026                                       What is the birthdate (mm/dd/yyyy) of Kevin Spacey?
# 29251                                   What is the birthdate (mm/dd/yyyy) of Laurence Olivier?
# 29261                                   What is the birthdate (mm/dd/yyyy) of Laurence Olivier?
# 29506                                         What is the birthdate (mm/dd/yyyy) of Lee Marvin?
# 29516                                         What is the birthdate (mm/dd/yyyy) of Lee Marvin?
# 30361                                 What is the birthdate (mm/dd/yyyy) of Leonardo Di Caprio?
# 30371                                 What is the birthdate (mm/dd/yyyy) of Leonardo Di Caprio?
# 29011                                   What is the birthdate (mm/dd/yyyy) of Lionel Barrymore?
# 29021                                   What is the birthdate (mm/dd/yyyy) of Lionel Barrymore?
# 28366                                      What is the birthdate (mm/dd/yyyy) of Liza Minnelli?
# 28376                                      What is the birthdate (mm/dd/yyyy) of Liza Minnelli?
# 28006                                      What is the birthdate (mm/dd/yyyy) of Loretta Young?
# 28016                                      What is the birthdate (mm/dd/yyyy) of Loretta Young?
# 28411                                    What is the birthdate (mm/dd/yyyy) of Louise Fletcher?
# 28421                                    What is the birthdate (mm/dd/yyyy) of Louise Fletcher?
# 27841                                       What is the birthdate (mm/dd/yyyy) of Luise Rainer?
# 27851                                       What is the birthdate (mm/dd/yyyy) of Luise Rainer?
# 27856                                       What is the birthdate (mm/dd/yyyy) of Luise Rainer?
# ...
# 28515            06/22/1949  date        entertainment
# 28950            06/22/1949  date        entertainment
# 28525            06/22/1949  date        entertainment
# 28960            06/22/1949  date        entertainment
# 28521            06/22/1949  date        entertainment
# 28956            06/22/1949  date        entertainment
# 27990            07/01/1916  date        entertainment
# 28035            07/01/1916  date        entertainment
# 28000            07/01/1916  date        entertainment
# 28045            07/01/1916  date        entertainment
# 27996            07/01/1916  date        entertainment
# 28041            07/01/1916  date        entertainment
# 28470            11/06/1946  date        entertainment
# 28545            11/06/1946  date        entertainment
# 28480            11/06/1946  date        entertainment
# 28555            11/06/1946  date        entertainment
# 28476            11/06/1946  date        entertainment
# 28551            11/06/1946  date        entertainment
# 30075            08/17/1960  date        entertainment
# 30150            08/17/1960  date        entertainment
# 30085            08/17/1960  date        entertainment
# 30160            08/17/1960  date        entertainment
# 30081            08/17/1960  date        entertainment
# 30156            08/17/1960  date        entertainment
# 29085            04/05/1900  date        entertainment
# 29100            04/05/1900  date        entertainment
# 29095            04/05/1900  date        entertainment
# 29110            04/05/1900  date        entertainment
# 29091            04/05/1900  date        entertainment
# 29106            04/05/1900  date        entertainment
# 29925            07/09/1956  date        entertainment
# 29940            07/09/1956  date        entertainment
# 29935            07/09/1956  date        entertainment
# 29950            07/09/1956  date        entertainment
# 29931            07/09/1956  date        entertainment
# 29946            07/09/1956  date        entertainment
# 27885            11/05/1913  date        entertainment
# 28065            11/05/1913  date        entertainment
# 27895            11/05/1913  date        entertainment
# 28075            11/05/1913  date        entertainment
# 27891            11/05/1913  date        entertainment
# 28071            11/05/1913  date        entertainment
# 24204    Lawrence of Arabia  name        entertainment
# 24219  Mutiny on the Bounty  name        entertainment
# 24202    Lawrence of Arabia  name        entertainment
# 24217  Mutiny on the Bounty  name        entertainment
# 24196    Lawrence of Arabia  name        entertainment
# 24211  Mutiny on the Bounty  name        entertainment
# 21961     Jennifer Lawrence  name        entertainment
# 23401     Jennifer Lawrence  name        entertainment
# 21976        Cate Blanchett  name        entertainment
# 23416        Cate Blanchett  name        entertainment
# 21991       Julianne Moore   name        entertainment
# 23431        Julianne Moore  name        entertainment
# 22006           Brie Larson  name        entertainment
# 23446           Brie Larson  name        entertainment
# 22021           Emma Stone   name        entertainment
# 23461            Emma Stone  name        entertainment
# 22036     Frances McDormand  name        entertainment
# 23476     Frances McDormand  name        entertainment
# 22051         Olivia Colman  name        entertainment
# 23491         Olivia Colman  name        entertainment
# 24199    Lawrence of Arabia  name        entertainment
# 24214  Mutiny on the Bounty  name        entertainment
# 24207    Lawrence of Arabia  name        entertainment
# 24222  Mutiny on the Bounty  name        entertainment
# 24209    Lawrence of Arabia  name        entertainment
# 24224  Mutiny on the Bounty  name        entertainment
# 21964     Jennifer Lawrence  name        entertainment
# 23404     Jennifer Lawrence  name        entertainment
# 21979        Cate Blanchett  name        entertainment
# 23419        Cate Blanchett  name        entertainment
# 21994       Julianne Moore   name        entertainment
# 23434        Julianne Moore  name        entertainment
# 22009           Brie Larson  name        entertainment
# 23449           Brie Larson  name        entertainment
# 22024           Emma Stone   name        entertainment
# 23464            Emma Stone  name        entertainment
# 22039     Frances McDormand  name        entertainment
# 23479     Frances McDormand  name        entertainment
# 22054         Olivia Colman  name        entertainment
# 23494         Olivia Colman  name        entertainment
# 670      Estadio Centenario  name               Sports
# 1000     Estadio Centenario  name               Sports
# 666      Estadio Centenario  name               Sports
# 996      Estadio Centenario  name               Sports
# 663      Estadio Centenario  name               Sports
# 993      Estadio Centenario  name               Sports
# 667      Estadio Centenario  name               Sports
# 997      Estadio Centenario  name               Sports
# 21973     Jennifer Lawrence  name        entertainment
# 23413     Jennifer Lawrence  name        entertainment
# 21988        Cate Blanchett  name        entertainment
# 23428        Cate Blanchett  name        entertainment
# 22003       Julianne Moore   name        entertainment
# 23443        Julianne Moore  name        entertainment
# 22018           Brie Larson  name        entertainment
# 23458           Brie Larson  name        entertainment
# 22033           Emma Stone   name        entertainment
# 23473            Emma Stone  name        entertainment
# 22048     Frances McDormand  name        entertainment
# 23488     Frances McDormand  name        entertainment
# 22063         Olivia Colman  name        entertainment
# 23503         Olivia Colman  name        entertainment
# 21968     Jennifer Lawrence  name        entertainment
# 23408     Jennifer Lawrence  name        entertainment
# 21983        Cate Blanchett  name        entertainment
# 23423        Cate Blanchett  name        entertainment
# 21998       Julianne Moore   name        entertainment
# 23438        Julianne Moore  name        entertainment
# 22013           Brie Larson  name        entertainment
# 23453           Brie Larson  name        entertainment
# 22028           Emma Stone   name        entertainment
# 23468            Emma Stone  name        entertainment
# 22043     Frances McDormand  name        entertainment
# 23483     Frances McDormand  name        entertainment
# 22058         Olivia Colman  name        entertainment
# 23498         Olivia Colman  name        entertainment
# 21967     Jennifer Lawrence  name        entertainment
# 23407     Jennifer Lawrence  name        entertainment
# 21982        Cate Blanchett  name        entertainment
# 23422        Cate Blanchett  name        entertainment
# 21997       Julianne Moore   name        entertainment
# 23437        Julianne Moore  name        entertainment
# 22012           Brie Larson  name        entertainment
# 23452           Brie Larson  name        entertainment
# 22027           Emma Stone   name        entertainment
# 23467            Emma Stone  name        entertainment
# 22042     Frances McDormand  name        entertainment
# 23482     Frances McDormand  name        entertainment
# 22057         Olivia Colman  name        entertainment
# 23497         Olivia Colman  name        entertainment
# 21972     Jennifer Lawrence  name        entertainment
# 23412     Jennifer Lawrence  name        entertainment
# 21987        Cate Blanchett  name        entertainment
# 23427        Cate Blanchett  name        entertainment
# 22002       Julianne Moore   name        entertainment
# 23442        Julianne Moore  name        entertainment
# 22017           Brie Larson  name        entertainment
# 23457           Brie Larson  name        entertainment
# 22032           Emma Stone   name        entertainment
# 23472            Emma Stone  name        entertainment
# 22047     Frances McDormand  name        entertainment
# 23487     Frances McDormand  name        entertainment
# 22062         Olivia Colman  name        entertainment
# 23502         Olivia Colman  name        entertainment
# 21962     Jennifer Lawrence  name        entertainment
# 23402     Jennifer Lawrence  name        entertainment
# 21977        Cate Blanchett  name        entertainment
# 23417        Cate Blanchett  name        entertainment
# 21992       Julianne Moore   name        entertainment
# 23432        Julianne Moore  name        entertainment
# 22007           Brie Larson  name        entertainment
# 23447           Brie Larson  name        entertainment
# 22022           Emma Stone   name        entertainment
# 23462            Emma Stone  name        entertainment
# 22037     Frances McDormand  name        entertainment
# 23477     Frances McDormand  name        entertainment
# 22052         Olivia Colman  name        entertainment
# 23492         Olivia Colman  name        entertainment
# 21970     Jennifer Lawrence  name        entertainment
# 23410     Jennifer Lawrence  name        entertainment
# 21985        Cate Blanchett  name        entertainment
# 23425        Cate Blanchett  name        entertainment
# 22000       Julianne Moore   name        entertainment
# 23440        Julianne Moore  name        entertainment
# 22015           Brie Larson  name        entertainment
# 23455           Brie Larson  name        entertainment
# 22030           Emma Stone   name        entertainment
# 23470            Emma Stone  name        entertainment
# 22045     Frances McDormand  name        entertainment
# 23485     Frances McDormand  name        entertainment
# 22060         Olivia Colman  name        entertainment
# 23500         Olivia Colman  name        entertainment
# 21974     Jennifer Lawrence  name        entertainment
# 23414     Jennifer Lawrence  name        entertainment
# 21989        Cate Blanchett  name        entertainment
# 23429        Cate Blanchett  name        entertainment
# 22004       Julianne Moore   name        entertainment
# 23444        Julianne Moore  name        entertainment
# 22019           Brie Larson  name        entertainment
# 23459           Brie Larson  name        entertainment
# 22034           Emma Stone   name        entertainment
# 23474            Emma Stone  name        entertainment
# 22049     Frances McDormand  name        entertainment
# 23489     Frances McDormand  name        entertainment
# 22064         Olivia Colman  name        entertainment
# 23504         Olivia Colman  name        entertainment
# 21960     Jennifer Lawrence  name        entertainment
# 23400     Jennifer Lawrence  name        entertainment
# 21975        Cate Blanchett  name        entertainment
# 23415        Cate Blanchett  name        entertainment
# 21990       Julianne Moore   name        entertainment
# 23430        Julianne Moore  name        entertainment
# 22005           Brie Larson  name        entertainment
# 23445           Brie Larson  name        entertainment
# 22020           Emma Stone   name        entertainment
# 23460            Emma Stone  name        entertainment
# 22035     Frances McDormand  name        entertainment
# 23475     Frances McDormand  name        entertainment
# 22050         Olivia Colman  name        entertainment
# 23490         Olivia Colman  name        entertainment
# 21965     Jennifer Lawrence  name        entertainment
# 23405     Jennifer Lawrence  name        entertainment
# 21980        Cate Blanchett  name        entertainment
# 23420        Cate Blanchett  name        entertainment
# 21995       Julianne Moore   name        entertainment
# 23435        Julianne Moore  name        entertainment
# 22010           Brie Larson  name        entertainment
# 23450           Brie Larson  name        entertainment
# 22025           Emma Stone   name        entertainment
# 23465            Emma Stone  name        entertainment
# 22040     Frances McDormand  name        entertainment
# 23480     Frances McDormand  name        entertainment
# 22055         Olivia Colman  name        entertainment
# 23495         Olivia Colman  name        entertainment
# 21966     Jennifer Lawrence  name        entertainment
# 23406     Jennifer Lawrence  name        entertainment
# 21981        Cate Blanchett  name        entertainment
# 23421        Cate Blanchett  name        entertainment
# 21996       Julianne Moore   name        entertainment
# 23436        Julianne Moore  name        entertainment
# 22011           Brie Larson  name        entertainment
# 23451           Brie Larson  name        entertainment
# 22026           Emma Stone   name        entertainment
# 23466            Emma Stone  name        entertainment
# 22041     Frances McDormand  name        entertainment
# 23481     Frances McDormand  name        entertainment
# 22056         Olivia Colman  name        entertainment
# 23496         Olivia Colman  name        entertainment
# 21971     Jennifer Lawrence  name        entertainment
# 23411     Jennifer Lawrence  name        entertainment
# 21986        Cate Blanchett  name        entertainment
# 23426        Cate Blanchett  name        entertainment
# 22001       Julianne Moore   name        entertainment
# 23441        Julianne Moore  name        entertainment
# 22016           Brie Larson  name        entertainment
# 23456           Brie Larson  name        entertainment
# 22031           Emma Stone   name        entertainment
# 23471            Emma Stone  name        entertainment
# 22046     Frances McDormand  name        entertainment
# 23486     Frances McDormand  name        entertainment
# 22061         Olivia Colman  name        entertainment
# 23501         Olivia Colman  name        entertainment
# 21969     Jennifer Lawrence  name        entertainment
# 23409     Jennifer Lawrence  name        entertainment
# 21984        Cate Blanchett  name        entertainment
# 23424        Cate Blanchett  name        entertainment
# 21999       Julianne Moore   name        entertainment
# 23439        Julianne Moore  name        entertainment
# 22014           Brie Larson  name        entertainment
# 23454           Brie Larson  name        entertainment
# 22029           Emma Stone   name        entertainment
# 23469            Emma Stone  name        entertainment
# 22044     Frances McDormand  name        entertainment
# 23484     Frances McDormand  name        entertainment
# 22059         Olivia Colman  name        entertainment
# 23499         Olivia Colman  name        entertainment
# 21963     Jennifer Lawrence  name        entertainment
# 23403     Jennifer Lawrence  name        entertainment
# 21978        Cate Blanchett  name        entertainment
# 23418        Cate Blanchett  name        entertainment
# 21993       Julianne Moore   name        entertainment
# 23433        Julianne Moore  name        entertainment
# 22008           Brie Larson  name        entertainment
# 23448           Brie Larson  name        entertainment
# 22023           Emma Stone   name        entertainment
# 23463            Emma Stone  name        entertainment
# 22038     Frances McDormand  name        entertainment
# 23478     Frances McDormand  name        entertainment
# 22053         Olivia Colman  name        entertainment
# 23493         Olivia Colman  name        entertainment
# 24203    Lawrence of Arabia  name        entertainment
# 24218  Mutiny on the Bounty  name        entertainment
# 30994            09/20/1960  date  World Organizations
# 31114            09/20/1960  date  World Organizations
# 31002            09/20/1960  date  World Organizations
# 31122            09/20/1960  date  World Organizations
# 31004            09/20/1960  date  World Organizations
# 31124            09/20/1960  date  World Organizations

# %%
# a quick scan shows that some of these duplicated questions even have more than one distinct answer
# e.g., it was lawrence of arabia that won best picture at the oscars in 1962, not mutiny on the bounty...
# let's check to see if this is an issue elsewhere too

# first stop showing all rows, this is dangerous -- df is long
pd.reset_option("display.max_rows")

# %%
# now store a copy of the duplicates in memory
dup = df[df["questions"].duplicated(keep=False)].copy()

# clean whitespace so cosmetic differences don't count as different answers
dup["answer"] = (
    dup["answer"]
        .astype(str)
        .str.replace(r"\s+", " ", regex=True)
        .str.strip()
)

answer_counts = dup.groupby("questions")["answer"].nunique()
bad_questions = answer_counts[answer_counts > 1].index

df_bad = dup[dup["questions"].isin(bad_questions)].sort_values(["questions", "answer"])

df_bad
# Out:
#                                                                        questions  \
# 24200           In 1962, which film was honored with the Oscar for best picture?
# 24215           In 1962, which film was honored with the Oscar for best picture?
# 24205                   In 1962, which movie snagged the Oscar for best picture?
# 24220                   In 1962, which movie snagged the Oscar for best picture?
# 24197                 In 1962, which movie took home the Oscar for best picture?
# 24212                 In 1962, which movie took home the Oscar for best picture?
# 24208            What film was bestowed with the Oscar for best picture in 1962?
# 24223            What film was bestowed with the Oscar for best picture in 1962?
# 24198                          What film won the Oscar for best picture in 1962?
# 24213                          What film won the Oscar for best picture in 1962?
# 24195                    What movie received the Oscar for best picture in 1962?
# 24210                    What movie received the Oscar for best picture in 1962?
# 24201                  What was the Oscar-winning film for best picture in 1962?
# 24216                  What was the Oscar-winning film for best picture in 1962?
# 24206             What was the winning film for best picture at the 1962 Oscars?
# 24221             What was the winning film for best picture at the 1962 Oscars?
# 24204  Which film emerged victorious in the Oscar race for best picture in 1962?
# 24219  Which film emerged victorious in the Oscar race for best picture in 1962?
# 24202                     Which film secured the Oscar for best picture in 1962?
# 24217                     Which film secured the Oscar for best picture in 1962?
# 24196                 Which film was awarded the Oscar for best picture in 1962?
# 24211                 Which film was awarded the Oscar for best picture in 1962?
# 24199                    Which movie claimed the Oscar for best picture in 1962?
# 24214                    Which movie claimed the Oscar for best picture in 1962?
# 24207                       Which movie received the best picture Oscar in 1962?
# 24222                       Which movie received the best picture Oscar in 1962?
# 24209               Which movie was honored with the best picture Oscar in 1962?
# 24224               Which movie was honored with the best picture Oscar in 1962?
# 24203                                                best picture in 1962 Oscar?
# 24218                                                best picture in 1962 Oscar?
#
#                      answer  type         domain
# 24200    Lawrence of Arabia  name  entertainment
# 24215  Mutiny on the Bounty  name  entertainment
# 24205    Lawrence of Arabia  name  entertainment
# 24220  Mutiny on the Bounty  name  entertainment
# 24197    Lawrence of Arabia  name  entertainment
# 24212  Mutiny on the Bounty  name  entertainment
# 24208    Lawrence of Arabia  name  entertainment
# 24223  Mutiny on the Bounty  name  entertainment
# 24198    Lawrence of Arabia  name  entertainment
# 24213  Mutiny on the Bounty  name  entertainment
# 24195    Lawrence of Arabia  name  entertainment
# 24210  Mutiny on the Bounty  name  entertainment
# 24201    Lawrence of Arabia  name  entertainment
# 24216  Mutiny on the Bounty  name  entertainment
# 24206    Lawrence of Arabia  name  entertainment
# 24221  Mutiny on the Bounty  name  entertainment
# 24204    Lawrence of Arabia  name  entertainment
# 24219  Mutiny on the Bounty  name  entertainment
# 24202    Lawrence of Arabia  name  entertainment
# 24217  Mutiny on the Bounty  name  entertainment
# 24196    Lawrence of Arabia  name  entertainment
# 24211  Mutiny on the Bounty  name  entertainment
# 24199    Lawrence of Arabia  name  entertainment
# 24214  Mutiny on the Bounty  name  entertainment
# 24207    Lawrence of Arabia  name  entertainment
# 24222  Mutiny on the Bounty  name  entertainment
# 24209    Lawrence of Arabia  name  entertainment
# 24224  Mutiny on the Bounty  name  entertainment
# 24203    Lawrence of Arabia  name  entertainment
# 24218  Mutiny on the Bounty  name  entertainment

# %%
# alright, looks like this was just a fluke. (a check that this doesn't happen among non-dupes either is skipped here but can be found at the end of the notebook)
# let's keep cleaning.
# we should first get rid of all the erroneous 'mutiny on the bounty' rows.


mask = (
    df["answer"].str.contains("Mutiny", case=False, na=False) &
    df["questions"].str.contains("1962", case=False, na=False)
)

df = df[~mask]

df[df["answer"].str.contains("Mutiny", case=False, na=False)]
# Out:
#                                                                        questions  \
# 23790                    What movie received the Oscar for best picture in 1935?
# 23791                 Which film was awarded the Oscar for best picture in 1935?
# 23792                 In 1935, which movie took home the Oscar for best picture?
# 23793                          What film won the Oscar for best picture in 1935?
# 23794                    Which movie claimed the Oscar for best picture in 1935?
# 23795           In 1935, which film was honored with the Oscar for best picture?
# 23796                  What was the Oscar-winning film for best picture in 1935?
# 23797                     Which film secured the Oscar for best picture in 1935?
# 23798                                                best picture in 1935 Oscar?
# 23799  Which film emerged victorious in the Oscar race for best picture in 1935?
# 23800                   In 1935, which movie snagged the Oscar for best picture?
# 23801             What was the winning film for best picture at the 1935 Oscars?
# 23802                       Which movie received the best picture Oscar in 1935?
# 23803            What film was bestowed with the Oscar for best picture in 1935?
# 23804               Which movie was honored with the best picture Oscar in 1935?
#
#                      answer  type         domain
# 23790  Mutiny on the Bounty  name  entertainment
# 23791  Mutiny on the Bounty  name  entertainment
# 23792  Mutiny on the Bounty  name  entertainment
# 23793  Mutiny on the Bounty  name  entertainment
# 23794  Mutiny on the Bounty  name  entertainment
# 23795  Mutiny on the Bounty  name  entertainment
# 23796  Mutiny on the Bounty  name  entertainment
# 23797  Mutiny on the Bounty  name  entertainment
# 23798  Mutiny on the Bounty  name  entertainment
# 23799  Mutiny on the Bounty  name  entertainment
# 23800  Mutiny on the Bounty  name  entertainment
# 23801  Mutiny on the Bounty  name  entertainment
# 23802  Mutiny on the Bounty  name  entertainment
# 23803  Mutiny on the Bounty  name  entertainment
# 23804  Mutiny on the Bounty  name  entertainment

# %%
# now let's get rid of all the actual duplicates
# note: we're not counting questions with the same semantic content but phrased slightly differently as duplicates

# first, make a cleaned key for "same literal question up to whitespace/case"
df["questions_clean"] = (
    df["questions"].astype(str)
                   .str.replace(r"\s+", " ", regex=True)
                   .str.strip()
                   .str.lower()
)

# now drop the duplicates and remove the cleaned key column
df = df.drop_duplicates(subset=["questions_clean"], keep="first")
df = df.drop(columns=["questions_clean"])

# %%
print(df["questions"].duplicated().any())
# Out:
# False

# %%
# finally, let's sample for the 500 questions we want to use for data generation
# probably an even spread across domains will be good...
# i dont know a good way of disallowing semantic duplicates, so i'll just ignore it and let them be for now

print(df["domain"].value_counts(normalize=True) * 100)
# Out:
# domain
# QS ranking             30.643667
# math                   21.695060
# entertainment          15.386699
# Nobel Prize            13.963932
# Census Australia       11.269513
# World Organizations     3.891938
# Sports                  1.844750
# Conference venue        1.304441
# Name: proportion, dtype: float64

# %%
n_total = 500
domains = df["domain"].unique()
k = len(domains)

base = n_total // k
remainder = n_total % k

pieces = []

for i, d in enumerate(domains):
    n = base + (i < remainder)   # first 'remainder' domains get +1
    pieces.append(df[df["domain"] == d].sample(n=n, random_state=0))

sampled = pd.concat(pieces, ignore_index=True)

# %%
sampled["domain"].value_counts()  # should be 62/63 each
# Out:
# domain
# Sports                 63
# Census Australia       63
# Nobel Prize            63
# entertainment          63
# World Organizations    62
# QS ranking             62
# Conference venue       62
# math                   62
# Name: count, dtype: int64

# %%
# alright, now we just need to export the questions to json

sampled = sampled.reset_index(drop=True)
sampled["id"] = ["q_%03d" % i for i in range(len(sampled))]
sampled.to_json("sampled_from_defan_500.jsonl", orient="records", lines=True)

# %%
# let's do a quick check to make sure there's no more contradictory cases like the lawrence-mutiny situation

# clean both columns (so whitespace/case doesn't create fake differences)
df["questions_clean"] = (
    df["questions"].astype(str)
                   .str.replace(r"\s+", " ", regex=True)
                   .str.strip()
                   .str.lower()
)

df["answer_clean"] = (
    df["answer"].astype(str)
                .str.replace(r"\s+", " ", regex=True)
                .str.strip()
                .str.lower()
)

# find questions that map to >1 distinct answer
answer_counts = df.groupby("questions_clean")["answer_clean"].nunique()
bad_questions = answer_counts[answer_counts > 1].index

# inspect all contradictory rows
contradictions = df[df["questions_clean"].isin(bad_questions)] \
    .sort_values(["questions_clean", "answer_clean"])

contradictions
# Out:
# Empty DataFrame
# Columns: [questions, answer, type, domain, questions_clean, answer_clean]
# Index: []

# %%
# all good!
